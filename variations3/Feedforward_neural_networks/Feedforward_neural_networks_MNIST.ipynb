# %%
# a. Import necessary packages
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.utils import to_categorical

# %%
# b. Load the training and testing data
(x_train, y_train), (x_test, y_test)=tf.keras.datasets.mnist.load_data()
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0
y_train=to_categorical(y_train,10)
y_test=to_categorical(y_test,10)

# %%
# c. Define the network architecture using Keras
model=models.Sequential([
    layers.Flatten(input_shape=(28,28)),
    layers.Dense(128,activation='relu'),
    layers.Dense(10,activation='softmax')
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# d. Train the model using SGD with 11 epochs
model.compile(optimizer='sgd',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
history=model.fit(x_train,y_train,epochs=11,validation_data=(x_test,y_test))
# Out:
# Epoch 1/11
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.7145 - loss: 1.0919 - val_accuracy: 0.9031 - val_loss: 0.3611
# Epoch 2/11
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.9005 - loss: 0.3569 - val_accuracy: 0.9174 - val_loss: 0.2935
# Epoch 3/11
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9145 - loss: 0.3025 - val_accuracy: 0.9259 - val_loss: 0.2641
# Epoch 4/11
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9248 - loss: 0.2646 - val_accuracy: 0.9328 - val_loss: 0.2378
# Epoch 5/11
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9326 - loss: 0.2433 - val_accuracy: 0.9365 - val_loss: 0.2212
# Epoch 6/11
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9408 - loss: 0.2161 - val_accuracy: 0.9396 - val_loss: 0.2086
# Epoch 7/11
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9437 - loss: 0.2031 - val_accuracy: 0.9446 - val_loss: 0.1933
# Epoch 8/11
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9481 - loss: 0.1878 - val_accuracy: 0.9471 - val_loss: 0.1819
# Epoch 9/11
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9489 - loss: 0.1834 - val_accuracy: 0.9500 - val_loss: 0.1741
# Epoch 10/11
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9515 - loss: 0.1706 - val_accuracy: 0.9531 - val_loss: 0.1642
# Epoch 11/11
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9543 - loss: 0.1613 - val_accuracy: 0.9537 - val_loss: 0.1567

# %%
test_loss,test_acc=model.evaluate(x_test,y_test)
print(f"Test accuracy: {test_acc}\n")
print(f"Test loss: {test_loss}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9443 - loss: 0.1862
# Test accuracy: 0.9537000060081482
#
# Test loss: 0.1567292958498001

# %%
# f. Plot the training loss and accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
import numpy as np

# %%
n=16
plt.imshow(x_test[n].reshape(28,28),cmap='gray')
plt.title("Actual label")
plt.show()

predicted=model.predict(x_test[n].reshape(1,28,28))
print("Actual ",np.argmax(y_test[n]))
print("Predicted  ",np.argmax(predicted))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Actual  9
# Predicted   9
